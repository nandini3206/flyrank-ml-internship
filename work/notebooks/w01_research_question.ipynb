# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## My Lane (or Freestyle) and Why

**Selected Lane:** Lane 2 – Refresh / Content Opportunity Scoring

I selected Lane 2 because it focuses on identifying which webpages should be prioritized for refresh, expansion, protection, pruning, or monitoring. Instead of manually reviewing every page, this approach uses data to help content teams make informed decisions. It is a practical machine learning problem that combines exploratory data analysis with predictive modeling to support better content optimization.
"""))
# Out:
# ## My Lane (or Freestyle) and Why
#
# **Selected Lane:** Lane 2 – Refresh / Content Opportunity Scoring
#
# I selected Lane 2 because it focuses on identifying which webpages should be prioritized for refresh, expansion, protection, pruning, or monitoring. Instead of manually reviewing every page, this approach uses data to help content teams make informed decisions. It is a practical machine learning problem that combines exploratory data analysis with predictive modeling to support better content optimization.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Research Question, Decision, Action, and Cost of a Wrong Call

### Research Question
Which webpages should be reviewed first for refresh, expansion, protection, pruning, or monitoring?

### Decision
Identify and prioritize webpages that have the highest potential for improvement based on their search performance and content metrics.

### Action
The SEO or content team will review the recommended webpages first and decide whether to refresh, expand, protect, prune, or monitor them.

### Cost of a Wrong Recommendation
If the recommendation is incorrect, the team may spend time improving pages that do not need attention while missing pages that actually require updates. This can waste resources, reduce optimization efficiency, and negatively impact website performance.
"""))
# Out:
# ## Research Question, Decision, Action, and Cost of a Wrong Call
#
# ### Research Question
# Which webpages should be reviewed first for refresh, expansion, protection, pruning, or monitoring?
#
# ### Decision
# Identify and prioritize webpages that have the highest potential for improvement based on their search performance and content metrics.
#
# ### Action
# The SEO or content team will review the recommended webpages first and decide whether to refresh, expand, protect, prune, or monitor them.
#
# ### Cost of a Wrong Recommendation
# If the recommendation is incorrect, the team may spend time improving pages that do not need attention while missing pages that actually require updates. This can waste resources, reduce optimization efficiency, and negatively impact website performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from IPython.display import Markdown, display

display(Markdown("## Quick Look at the Data"))

print(f"Total webpages in dataset: {len(df):,}")
print(f"Total features (columns): {df.shape[1]}")

print("\nAverage Search Volume:",
      round(df["search_volume"].mean(),2))

print("Average Word Count:",
      round(df["word_count"].mean(),2))

print("Average CTR:",
      round(df["ctr"].mean(),3))
# Out:
# ## Quick Look at the Data
# Total webpages in dataset: 30,000
# Total features (columns): 44
#
# Average Search Volume: 158.88
# Average Word Count: 3107.76
# Average CTR: 0.511

# %%
from IPython.display import Markdown, display

display(Markdown("""
### Why this supports my lane

The starter dataset contains **30,000 webpages** described by **44 features**. The average search volume (**158.88**), average word count (**3107.76**), and average CTR (**0.511**) show that the dataset contains meaningful information for analyzing webpage performance. These metrics provide a good foundation for identifying which pages should be prioritized for refresh, expansion, protection, pruning, or monitoring.
"""))
# Out:
# ### Why this supports my lane
#
# The starter dataset contains **30,000 webpages** described by **44 features**. The average search volume (**158.88**), average word count (**3107.76**), and average CTR (**0.511**) show that the dataset contains meaningful information for analyzing webpage performance. These metrics provide a good foundation for identifying which pages should be prioritized for refresh, expansion, protection, pruning, or monitoring.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
from IPython.display import Markdown, display

display(Markdown("""
## Careful Words

This work analyzes patterns and relationships observed in the available data to support content prioritization decisions. The results can help identify webpages that may deserve review, but they do not prove that any feature directly causes higher rankings or engagement. Any recommendations should be validated through further testing and human review before implementation.
"""))
# Out:
# ## Careful Words
#
# This work analyzes patterns and relationships observed in the available data to support content prioritization decisions. The results can help identify webpages that may deserve review, but they do not prove that any feature directly causes higher rankings or engagement. Any recommendations should be validated through further testing and human review before implementation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
